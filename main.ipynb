# %%
import json
import import_ipynb
from src.stat_engine import StatEngine
from src.monte_carlo import simulate_crashes

# Load data
with open("data/sample_data.json") as f:
    data = json.load(f)

engine = StatEngine(data)

print("Mean:", engine.get_mean())
print("Median:", engine.get_median())
print("Mode:", engine.get_mode())
print("Variance:", engine.get_variance())
print("Std Dev:", engine.get_standard_deviation())
print("Outliers:", engine.get_outliers())


# Simulation
prob = simulate_crashes(1000)
print("Simulated Probability:", prob)
# Out:
# Mean: 123860.0
# Median: 66500.0
# Mode: All values are unique
# Variance: 35268816734.69388
# Std Dev: 187799.93805828018
# Outliers: [500000, 750000, 1000000]
# Simulated Probability: 0.055
